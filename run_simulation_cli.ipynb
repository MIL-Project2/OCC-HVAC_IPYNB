# %% [markdown]
# <a href="https://colab.research.google.com/github/MIL-Project2/OCC-HVAC_IPYNB/blob/main/run_simulation_cli.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas scikit-learn joblib

# %% [markdown]
# # GitHub Setup

# %%
import os
import sys

from google.colab import userdata
PAT = userdata.get('GITHUB_PAT')
GITHUB_ORG = "MIL-Project2"
GITHUB_REPO = "OCC-HVAC_15"
REPO_URL = f"https://{PAT}@github.com/{GITHUB_ORG}/{GITHUB_REPO}.git"
REPO_PATH = f"/content/{GITHUB_REPO}"

# Clone the repo
if not os.path.exists(REPO_PATH):
    # !git clone {REPO_URL} {REPO_PATH}

# Change into the repo directory so the script can find its imports
# %cd {REPO_PATH}
# Out:
# Cloning into '/content/OCC-HVAC_15'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 39 (delta 13), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (39/39), 603.45 KiB | 1.88 MiB/s, done.
# Resolving deltas: 100% (13/13), done.
# /content/OCC-HVAC_15

# %%
# %cd /content/OCC-HVAC_15
# !git pull
# Out:
# /content/OCC-HVAC_15
# Already up to date.

# %% [markdown]
# # Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Verify the CSV file location

# %%
# !ls /content/
# Out:
# drive  OCC-HVAC_15  sample_data

# %% [markdown]
# # Run Simulation

# %%
# !python run_simulation_cli.py /content/drive/MyDrive/data/OccupancySensor_SelectedMonths.csv \
    --timestamp-col collecteddate \
    --headcount-col headcount \
    --output-dir /content/results/
# Out:
# Loaded model from 'occupancy_model_15min.pkl' (forecast horizon: 15 min)
# Computed forecast for 35419 timestamps.
# Note: no 'outdoor_temperature_C' column found in the data -- using a constant fallback of 27.0 deg C.
#
# Wrote:
#   /content/results/occupancy_forecast.csv
#   /content/results/hvac_comparison.csv
#   /content/results/hvac_summary.csv
#
# === KPIs: Scheduled vs Predictive ===
#                             KPI  Scheduled HVAC  Predictive HVAC  Difference (Predictive - Scheduled)
#         Total HVAC Energy (kWh)         146.306          111.368                              -34.938
#            Peak HVAC Power (kW)           1.667            1.110                               -0.557
# Occupied Comfort Compliance (%)          99.321           96.876                               -2.446
#         Occupied Discomfort (h)           5.250           24.167                               18.917
# ...

# %%
# import json
# from feature_engineering import MODEL_FEATURES

# with open('occupancy_model_15min_config.json') as f:
#     config_features = json.load(f)['features']

# print("feature_engineering.py MODEL_FEATURES:", MODEL_FEATURES)
# print("config.json features:              ", config_features)
# print("Same elements, different order?    ", sorted(MODEL_FEATURES) == sorted(config_features) and MODEL_FEATURES != config_features)
# print("In config but not in MODEL_FEATURES:", set(config_features) - set(MODEL_FEATURES))
# print("In MODEL_FEATURES but not in config:", set(MODEL_FEATURES) - set(config_features))

# %% [markdown]
# # Download csv files

# %%
from google.colab import files

# Download the summary KPI table
files.download('/content/results/hvac_summary.csv')

# Download the full timestep comparison
files.download('/content/results/hvac_comparison.csv')

# Download the occupancy forecast
files.download('/content/results/occupancy_forecast.csv')
